# %% [markdown]
# <a href="https://colab.research.google.com/github/ryaready/computational-data-science/blob/main/Week_3_CDS_Lab_3a_visualisation_(questions).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data visualisation in Python
#
# __Prof. Dorien Herremans__
#
#
# **Open the tutorial in 'File -> Playground mode'. Go through the tutorial first. You will find several `#TODO` slots for you to address. They should be easy if you read through in detail. There are a number of open questions for you to solve as well. **
#
#
# For a full overview of types of plots using matplotlib, see the gallery [at https://matplotlib.org/2.0.2/gallery.html](https://matplotlib.org/2.0.2/gallery.html)

# %% [markdown]
# ## Scatterplots
#
# We will be using scottish_hills.csv from [https://github.com/ourcodingclub/CC-python-pandas-matplotlib](https://github.com/ourcodingclub/CC-python-pandas-matplotlib). The file contains all the mountains above 3000 feet (about 914 metres) in Scotland.
#
# We can read this into a variable and see the first 10 lines.
#
# Use the dataframe.head(10) command along with print to have a look into the file.

# %%
import pandas as pd

dataframe = pd.read_csv("https://raw.githubusercontent.com/ourcodingclub/CC-python-pandas-matplotlib/master/scottish_hills.csv")


# TODO print out first 10 lines of the file
dataframe.head(10)
# Out:
#                     Hill Name  Height   Latitude  Longitude    Osgrid
# 0       A' Bhuidheanach Bheag   936.0  56.870342  -4.199001  NN660775
# 1               A' Chailleach   997.0  57.693800  -5.128715  NH136714
# 2               A' Chailleach   929.2  57.109564  -4.179285  NH681041
# 3  A' Chraileag (A' Chralaig)  1120.0  57.184186  -5.154837  NH094147
# 4             A' Ghlas-bheinn   918.0  57.255090  -5.303687  NH008231
# 5               A' Mhaighdean   967.0  57.719644  -5.346720  NH007749
# 6              A' Mharconaich   973.2  56.857002  -4.290668  NN604762
# 7                  Am Basteir   934.0  57.247931  -6.202982  NG465253
# 8                   Am Bodach  1031.8  56.741727  -4.983393  NN176650
# 9               Am Faochagach   953.0  57.771801  -4.853899  NH303793

# %% [markdown]
# As explored last week, pandas dataframes can be used for some preliminary data exploration. For instance, let's sort the hills by height:

# %%
sorted_hills = dataframe.sort_values(by=['Height'], ascending=False)

# Let's have a look at the top 5 to check
print(sorted_hills.head(5))
# Out:
#                        Hill Name  Height   Latitude  Longitude    Osgrid
# 92                     Ben Nevis  1344.5  56.796891  -5.003675  NN166712
# 88   Ben Macdui (Beinn Macduibh)  1309.0  57.070368  -3.669099  NN988989
# 104                    Braeriach  1296.0  57.078298  -3.728389  NN953999
# 115                   Cairn Toul  1291.0  57.054397  -3.710773  NN963972
# 212        Sgor an Lochain Uaine  1258.0  57.058369  -3.725797  NN954976

# %% [markdown]
# Now let's load matplotlib. Note: if you are using a jupyter notebook you need the inline statement on line 1 below:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# To save us some time, let's create some shortcut variables, x and y, to register the hight and latitude coordinates of each of the hills.

# %%
x = dataframe.Height
y = dataframe.Latitude
z = dataframe.Longitude

# %% [markdown]
# Now we are ready to start visualising them. Let's create (and save) a scatterplot. You can use the ` plt.scatter()` command with argument the height and latitude.

# %%
# TODO: create the scatterplot

plt.scatter(x, y)

plt.savefig("scottish_scatter_plot.png")

# %% [markdown]
# If you are not using iPython, you can use `plt.show()` to display the plot.
#
# Now let's build upon this graph by adding a linear regression line to it using the `linregress()` command and the same input variables as for scatterplot.

# %%
from scipy.stats import linregress
stats = linregress(x, y)



m = stats.slope
b = stats.intercept

# %% [markdown]
# Now we can add the plot of our linear regression by using the equation of a straight line.
#
# Add the equation of the linear regression based on the variables and slope/intercept calculated:

# %%
plt.scatter(x, y)
plt.plot(x, m*x+b, color="purple")  # The equation of the straight line.

# %% [markdown]
# Note, wether this line is statistically significant can be determined using the extra information in the stats object - `stats.rvalue` and `stats.pvalue`.

# %% [markdown]
# Now you can make your plot look nicer using arguments such as as fontsize, linewidth, color,...

# %%
# Change the default figure size
plt.figure(figsize=(10,10))

# Change the default marker for the scatter from circles to x's
plt.scatter(x, y, marker='x')

# Set the linewidth on the regression line to 3px
plt.plot(x, m*x+b, color="purple", linewidth=3)

# Add x and y lables, and set their font size
plt.xlabel("Height (m)", fontsize=20)
plt.ylabel("Latitude", fontsize=20)

# Set the font size of the number lables on the axes
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# Out:
# (array([56. , 56.5, 57. , 57.5, 58. , 58.5, 59. ]),
#  [Text(0, 56.0, '56.0'),
#   Text(0, 56.5, '56.5'),
#   Text(0, 57.0, '57.0'),
#   Text(0, 57.5, '57.5'),
#   Text(0, 58.0, '58.0'),
#   Text(0, 58.5, '58.5'),
#   Text(0, 59.0, '59.0')])

# %% [markdown]
# Let's have a look at how the hills our spread out geographically using latitude (y) and longitude (z). Now we can use s = x to say that the size needs to be equal to the height (x). (I added -900 to make the difference between big and small mountains larger)

# %%
import numpy as np

colors = np.random.rand(len(y))  #generates a different color for each different mountain

plt.scatter(y, z, s = (x-900), c=colors, alpha=0.5)

# %% [markdown]
# ## Histograms

# %% [markdown]
# Let's try some other graphs. A full selection is given at the [matplotlib website](https://matplotlib.org/2.0.2/examples/index.html).
#
# Let's start by looking at the distribution of our hills over the latitude (variable `y` from earlier):

# %%
plt.hist(x, bins=25) #bins separates the latitude in 25 discrete categories.

plt.savefig("histogram.png", dpi=25)  # results in 160x120 px image

# %% [markdown]
# Quickly style your plot with stylesheets, full overview [at https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html](https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html).
#
# Let's also create a new variable that contains the height of the hills -100m. This to illustrate how to add a second distribution to your graph. In this case, we will make them slightly transparent. Density makes sure the graph normalizes the data.
#
# Add a style to the graph using `plt.style.use()`

# %%
import numpy as np

# using a stylesheet:
# TODO add the style 'seaborn-pastel'
plt.style.use('seaborn-v0_8-pastel')

#creating the new height variable:
shifted_x = x - 100

fig, ax = plt.subplots() # lets us acces the axis and plot seperately.
ax.hist(x, bins=25, density=True, histtype="stepfilled", alpha=0.8,label='Height')
ax.hist(shifted_x, bins=25, density=True, histtype="stepfilled", alpha=0.8,label='Height - 100')
ax.legend(prop={'size': 10})

ax.set_ylabel('Distribution')
ax.set_xlabel('Height')
# Out:
# Text(0.5, 0, 'Height')

# %% [markdown]
# ## Bar charts
#
# Plot the average $CO_2$ output of both vegetarians and meat eaters for different continents in a bar plot. The data is given below.
#
# Add a legend to the ax using the `legend()` function and set an index value for the rects2 plot.

# %%
labels = ['EU', 'US', 'AS']

meateaters = [122, 135, 80]
vegetarians = [40, 43, 23]


# Keep a numeric index for the x-axis lables. This will be the positions of the ticks.
index = np.arange(len(labels))


fig, ax = plt.subplots()

# Toy with the below parameters to change the appearance of your graph:
bar_width = 0.35
opacity = 0.6

rects1 = ax.bar(index, meateaters, bar_width,
                alpha=opacity, color='b',
                label='Meat eaters')

# Note, shift the x postion also with the bar width so that the bar appears next to the previous one±
rects2 = ax.bar(index + bar_width,#TODO set an index which is shifted by the bar_width so that it's not entirely overlapping
                vegetarians, bar_width,
                alpha=opacity, color='r',
                label='Vegetarians')


ax.set_xlabel('Continent')
ax.set_ylabel('CO2 emissions')
ax.set_title('CO2 emissions per continent, per diet')

ax.set_xticks(index + bar_width / 2)

ax.set_xticklabels(labels)

#TODO add legend
# Out:
# [Text(0.175, 0, 'EU'), Text(1.175, 0, 'US'), Text(2.175, 0, 'AS')]

# %% [markdown]
# ## Line plots
#
# Let's move on to another type of graph: a simple line plot, but using two vertical axis.
#
# We will create a function to calculate the temperature in celcius given Fahrenheit. Add the function to calculate Calcius from the Fahrenheit `temp`.

# %%
def fahrenheit2celsius(temp):
    ctemp = (temp - 32)* (5/9)
    return ctemp


# TEMPURATURE AT EACH HOUR THROUGHOUT THE DAY (In Fahrenheit)
temperature = [100, 102, 106, 105, 90, 85, 85, 89, 100, 102, 103, 108, 100, 102, 106, 105, 90, 85, 85, 89, 100, 102, 103, 108]

# %% [markdown]
# We will use `twinx` to get a second set of axes. This allows us to plot the temperature evolution throughout the day using both C and F.

# %%
fig, ax_f = plt.subplots()
ax_c = ax_f.twinx()

#plot our data:
ax_f.plot(temperature)
ax_f.set_xlim(0, 24) #x-axis shows 24 hours

# set the axis limits:
y1, y2 = ax_f.get_ylim()
ax_c.set_ylim(fahrenheit2celsius(y1), fahrenheit2celsius(y2))
ax_c.figure.canvas.draw()

# change some axis labels
ax_f.set_title('Two scales: Fahrenheit and Celsius')
ax_f.set_ylabel('Fahrenheit')
ax_c.set_ylabel('Celsius')
ax_f.set_xlabel('Time (hour of day)')
# Out:
# Text(0.5, 23.52222222222222, 'Time (hour of day)')

# %% [markdown]
# Suppose we have a sinusoidal plot (formula line 2 below), and we want to fill it. First let's plot the sinusoid.

# %%
newx = np.linspace(0, 1, 500) # sample 500 X's linearly between 0 and 1
newy = np.sin(4 * np.pi * newx) * np.exp(-5 * newx) #formula for our sinusoidal graph

fig, ax = plt.subplots()  #plt.subplots()  lets us acces the axis and plot seperately.

ax.plot(newx, newy)

# %% [markdown]
# Then we can easily use the `fill()` command of ax to 'fill' the axes with the newly sampled data.

# %%
fig, ax = plt.subplots()
ax.fill(newx, newy)

#TODO fill the plot with the newly sampled data newx and newy

# %% [markdown]
# Axis labels can influence how we perceive the data. Let's have a look at this stock data.

# %%
# growth of stock A
stockA = [0, 10, 20, 30, 40, 60, 80, 140]

plt.plot(stockA)
# plt.ylim(bottom=0, top = 110)
plt.xlabel('Time')
plt.ylabel('Stock A price')
# Out:
# Text(0, 0.5, 'Stock A price')

# %% [markdown]
# Now let's change to a logaritmic axis. Other options here are `linear, log, logit, symlog`. I consolidated the code of the previous plot and put it below. Give it a try.

# %% [markdown]
# ```
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
#
# line, = ax.plot(stockA)
# ax.set_yscale('log') #change the scale here
#
# plt.xlabel('Time')
# plt.ylabel('Stock A price')
# ax.set_title('Logarithmic')
# ```

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

line, = ax.plot(stockA)
ax.set_yscale('linear') #change the scale here

plt.xlabel('Time')
plt.ylabel('Stock A price')
ax.set_title('Linear')
# Out:
# Text(0.5, 1.0, 'Linear')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

line, = ax.plot(stockA)
ax.set_yscale('symlog') #change the scale here

plt.xlabel('Time')
plt.ylabel('Stock A price')
ax.set_title('Symlog')
# Out:
# Text(0.5, 1.0, 'Symlog')

# %% [markdown]
# This illustrates how axes can deform the data...

# %% [markdown]
# ### Boxplots
#
# For all the mountains, let's see what their average height is, with standard deviation in a boxplot.

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ca264b00690>,
#   <matplotlib.lines.Line2D at 0x7ca264b00fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ca264b01a50>,
#   <matplotlib.lines.Line2D at 0x7ca264b02350>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ca264ab9a10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ca264b02d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ca264b03650>],
#  'means': []}

# %% [markdown]
# Easy enough. Now we can make this slightly nicer:

# %%
# notched plot
plt.figure()
plt.boxplot(x, 1)

# change outlier point symbols
plt.figure()
plt.boxplot(x, 0, 'gD')

# don't show outlier points
plt.figure()
plt.boxplot(x, 0, '')

# horizontal boxes
plt.figure()
plt.boxplot(x, 0, 'rs', 0)

# change whisker length
plt.figure()
plt.boxplot(x, 0, 'rs', 0, whis=0.75)
# Out:
# <ipython-input-44-1c88ca8cc7d1>:3: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 1)
# <ipython-input-44-1c88ca8cc7d1>:7: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, 'gD')
# <ipython-input-44-1c88ca8cc7d1>:11: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, '')
# <ipython-input-44-1c88ca8cc7d1>:15: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, 'rs', 0)
# <ipython-input-44-1c88ca8cc7d1>:19: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, 'rs', 0, whis=0.75)
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ca26344bb50>,
#   <matplotlib.lines.Line2D at 0x7ca263454750>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ca263455310>,
#   <matplotlib.lines.Line2D at 0x7ca263455ed0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ca26344ae50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ca263456b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ca263457650>],
#  'means': []}

# %% [markdown]
# # Now to try yourself - exercises (for checkoff):
#
# Load the dataset from `https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv`, and have a look at what it contains.
#
# Then create the following:
#
# 1. A __histogram__ of the salaries for women.
# 2. Add the men's salaries to this histogram.
# 3. Give your histogram a dark background and label the axes.
# 4. Next, please label the colors of the histogram so we know who is what (men vs women).
# 5. Instead of a histogram, create a __bar chart__ that lists the salary for women (y-axis) for each school.
# 6. Also add men to this bar chart.
# 7. Make the style nice and add labels.
# 8. Now create a nice __boxplot__ of the data, one for men, one for women (two box's same graph).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
df.head()
# Out:
#       School  Women  Men  Gap
# 0        MIT     94  152   58
# 1   Stanford     96  151   55
# 2    Harvard    112  165   53
# 3     U.Penn     92  141   49
# 4  Princeton     90  137   47

# %% [markdown]
# ## Solution: histogram

# %%
import matplotlib.pyplot as plt

# Extracting salaries
salaries_women = df["Women"]
salaries_men = df["Men"]

plt.style.use('dark_background')

plt.hist(salaries_women, bins=5, alpha=0.5, label="Women", color="cyan")
plt.hist(salaries_men, bins=5, alpha=0.5, label="Men", color="magenta")


plt.xlabel("Salary (in thousands)")
plt.ylabel("Frequency")
plt.title("Histogram of Salaries by Gender")

plt.legend()

plt.show()

# %% [markdown]
# ## Solution: Bar chart

# %%
plt.style.use("dark_background")

plt.figure(figsize=(10, 6))
width = 0.4
x = range(len(df))

plt.bar(x, df["Women"], width=width, label="Women", color="cyan", align='center')
plt.bar([i + width for i in x], df["Men"], width=width, label="Men", color="magenta", align='center')

plt.xlabel("School")
plt.ylabel("Salary (in thousands)")
plt.title("Salary Comparison by Gender")
plt.xticks([i + width / 2 for i in x], df["School"], rotation=30)
plt.legend()

# %% [markdown]
# ## Solution: Boxplot

# %%
import seaborn as sns

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[["Women", "Men"]], palette=["cyan", "magenta"])

plt.xlabel("Gender")
plt.ylabel("Salary (in thousands)")
plt.title("Salary Distribution by Gender")
plt.xticks(ticks=[0, 1], labels=["Women", "Men"])


plt.show()

# %% [markdown]
# Well done!

# %% [markdown]
# ## Interactive fun
#
# There are a lot of libraries available to make plots more dynamic, for instance: https://mode.com/blog/python-interactive-plot-libraries/
#
# Let's experiment a bit with Ploly: https://plotly.com/python/

# %%
import plotly.graph_objects as go
import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=go.Surface(z=z_data, showscale=False))
fig.update_layout(
    title='Mt Bruno Elevation',
    width=400, height=400,
    margin=dict(t=40, r=0, l=20, b=20)
)

name = 'default'
# Default parameters which are used when `layout.scene.camera` is not provided
camera = dict(
    up=dict(x=0, y=0, z=1),
    center=dict(x=0, y=0, z=0),
    eye=dict(x=1.25, y=1.25, z=1.25)
)

fig.update_layout(scene_camera=camera, title=name)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9a7942dc-829e-4bba-b517-9bd39921016e" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a7942dc-829e-4bba-b517-9bd39921016e")) {                    Plotly.newPlot(                        "9a7942dc-829e-4bba-b517-9bd39921016e",                        [{"showscale":false,"z":[[0.0,27.80985,49.61936,83.08067,116.6632,130.414,150.7206,220.1871,156.1536,148.6416,203.7845,206.0386,107.1618,68.36975,45.3359,49.96142,21.89279,17.02552,11.74317,14.75226,13.6671,5.677561,3.31234,1.156517,-0.147662],[1.0,27.71966,48.55022,65.21374,95.27666,116.9964,133.9056,152.3412,151.934,160.1139,179.5327,147.6184,170.3943,121.8194,52.58537,33.08871,38.40972,44.24843,69.5786,4.019351,3.050024,3.039719,2.996142,2.967954,1.999594],[2.0,30.4267,33.47752,44.80953,62.47495,77.43523,104.2153,102.7393,137.0004,186.0706,219.3173,181.7615,120.9154,143.1835,82.40501,48.47132,74.71461,60.0909,7.073525,6.089851,6.53745,6.666096,7.306965,5.73684,3.625628],[3.0,16.66549,30.1086,39.96952,44.12225,59.57512,77.56929,106.8925,166.5539,175.2381,185.2815,154.5056,83.0433,62.61732,62.33167,60.55916,55.92124,15.17284,8.248324,36.68087,61.93413,20.26867,68.58819,46.49812,0.2360095],[4.0,8.815617,18.3516,8.658275,27.5859,48.62691,60.18013,91.3286,145.7109,116.0653,106.2662,68.69447,53.10596,37.92797,47.95942,47.42691,69.20731,44.95468,29.17197,17.91674,16.25515,14.65559,17.26048,31.22245,46.71704],[5.0,6.628881,10.41339,24.81939,26.08952,30.1605,52.30802,64.71007,76.30823,84.63686,99.4324,62.52132,46.81647,55.76606,82.4099,140.2647,81.26501,56.45756,30.42164,17.28782,8.302431,2.981626,2.698536,5.886086,5.268358],[6.0,21.83975,6.63927,18.97085,32.89204,43.15014,62.86014,104.6657,130.2294,114.8494,106.9873,61.89647,55.55682,86.80986,89.27802,122.4221,123.9698,109.0952,98.41956,77.61374,32.49031,14.67344,7.370775,0.03711011,0.6423392],[7.0,53.34303,26.79797,6.63927,10.88787,17.2044,56.18116,79.70141,90.8453,98.27675,80.87243,74.7931,75.54661,73.4373,74.11694,68.1749,46.24076,39.93857,31.21653,36.88335,40.02525,117.4297,12.70328,1.729771,0.0],[8.0,25.66785,63.05717,22.1414,17.074,41.74483,60.27227,81.42432,114.444,102.3234,101.7878,111.031,119.2309,114.0777,110.5296,59.19355,42.47175,14.63598,6.944074,6.944075,27.74936,0.0,0.0,0.09449376,0.07732264],[9.0,12.827,69.20554,46.76293,13.96517,33.88744,61.82613,84.74799,121.122,145.2741,153.1797,204.786,227.9242,236.3038,228.3655,79.34425,25.93483,6.944074,6.944074,6.944075,7.553681,0.0,0.0,0.0,0.0],[10.0,0.0,68.66396,59.0435,33.35762,47.45282,57.8355,78.91689,107.8275,168.0053,130.9597,212.5541,165.8122,210.2429,181.1713,189.7617,137.3378,84.65395,8.677168,6.956576,8.468093,0.0,0.0,0.0,0.0],[11.0,0.0,95.17499,80.03818,59.89862,39.58476,50.28058,63.81641,80.61302,66.37824,198.7651,244.3467,294.2474,264.3517,176.4082,60.21857,77.41475,53.16981,56.16393,6.949235,7.531059,3.780177,0.0,0.0,0.0],[12.0,0.0,134.9879,130.3696,96.86325,75.70494,58.86466,57.20374,55.18837,78.128,108.5582,154.3774,319.1686,372.8826,275.4655,130.2632,54.93822,25.49719,8.047439,8.084393,5.115252,5.678269,0.0,0.0,0.0],[13.0,0.0,48.08919,142.5558,140.3777,154.7261,87.9361,58.11092,52.83869,67.14822,83.66798,118.9242,150.0681,272.9709,341.1366,238.664,190.2,116.8943,91.48672,14.0157,42.29277,5.115252,0.0,0.0,0.0],[14.0,0.0,54.1941,146.3839,99.48143,96.19411,102.9473,76.14089,57.7844,47.0402,64.36799,84.23767,162.7181,121.3275,213.1646,328.482,285.4489,283.8319,212.815,164.549,92.29631,7.244015,1.167,0.0,0.0],[15.0,0.0,6.919659,195.1709,132.5253,135.2341,89.85069,89.45549,60.29967,50.33806,39.17583,59.06854,74.52159,84.93402,187.1219,123.9673,103.7027,128.986,165.1283,249.7054,95.39966,10.00284,2.39255,0.0,0.0],[16.0,0.0,21.73871,123.1339,176.7414,158.2698,137 ...

# %% [markdown]
# Move the plot around to see how it's interactive. Check out many more of the solutions on the plotly demo site
#
# ## Exercise (for checkoff):
#
# * Take the scatterplot from the scottish hills before, but now, visualize the height of the point you are hoovering over dynamically. You can use the template from https://plotly.com/python/click-events/
#
# Be sure to end with `f.show()`

# %%
import plotly.graph_objects as go
import pandas as pd

# Read data from a csv
z_data = pd.read_csv("https://raw.githubusercontent.com/ourcodingclub/CC-python-pandas-matplotlib/master/scottish_hills.csv")

fig = go.Figure(data=go.Surface(z=z_data, showscale=False))
fig.update_layout(
    title='Scottish Hills Elevation',
    width=400, height=400,
    margin=dict(t=40, r=0, l=20, b=20)
)

name = 'default'
# Default parameters which are used when `layout.scene.camera` is not provided
camera = dict(
    up=dict(x=0, y=0, z=1),
    center=dict(x=0, y=0, z=0),
    eye=dict(x=1.25, y=1.25, z=1.25)
)

fig.update_layout(scene_camera=camera, title=name)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f173162-6bb9-4e60-93ae-9693deb84e34" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f173162-6bb9-4e60-93ae-9693deb84e34")) {                    Plotly.newPlot(                        "4f173162-6bb9-4e60-93ae-9693deb84e34",                        [{"showscale":false,"z":[["A' Bhuidheanach Bheag",936.0,56.870342,-4.199001,"NN660775"],["A' Chailleach",997.0,57.6938,-5.128715,"NH136714"],["A' Chailleach",929.2,57.109564,-4.179285,"NH681041"],["A' Chraileag (A' Chralaig)",1120.0,57.184186,-5.154837,"NH094147"],["A' Ghlas-bheinn",918.0,57.25509,-5.303687,"NH008231"],["A' Mhaighdean",967.0,57.719644,-5.34672,"NH007749"],["A' Mharconaich",973.2,56.857002,-4.290668,"NN604762"],["Am Basteir",934.0,57.247931,-6.202982,"NG465253"],["Am Bodach",1031.8,56.741727,-4.983393,"NN176650"],["Am Faochagach",953.0,57.771801,-4.853899,"NH303793"],["An Caisteal",995.8,56.3386,-4.624368,"NN378193"],["An Coileachan",923.9,57.667625,-4.949498,"NH241680"],["An Gearanach",981.4,56.759143,-4.966203,"NN187669"],["An Riabhachan",1129.0,57.362429,-5.104728,"NH133344"],["An Sgarsoch",1006.5,56.932109,-3.754294,"NN933836"],["An Socach",1069.0,57.350229,-5.158603,"NH100332"],["An Socach",944.0,56.902286,-3.513148,"NO079800"],["An Socach",921.0,57.257533,-5.171293,"NH088229"],["An Stuc",1117.1,56.560093,-4.216258,"NN638431"],["An Teallach-Bidein a' Ghlas Thuill",1062.5,57.807098,-5.251767,"NH068843"],["An Teallach-Sgurr Fiona",1058.6,57.800726,-5.259443,"NH064836"],["Aonach air Chrith",1019.5,57.12464,-5.221291,"NH051083"],["Aonach Beag",1234.0,56.799998,-4.954121,"NN197715"],["Aonach Beag",1115.8,56.833496,-4.529181,"NN457741"],["Aonach Eagach-Meall Dearg",952.2,56.68072,-5.003271,"NN161583"],["Aonach Eagach-Sgorr nam Fiannaidh",967.7,56.679369,-5.037125,"NN140583"],["Aonach Meadhoin",1001.0,57.173082,-5.229121,"NH048137"],["Aonach Mor",1221.0,56.812932,-4.961744,"NN193729"],["Beinn a' Bheithir-Sgorr Dhearg",1024.0,56.653921,-5.17151,"NN056558"],["Beinn a' Bheithir-Sgorr Dhonuill",1001.0,56.650499,-5.197757,"NN040555"],["Beinn a' Bhuird (Beinn a' Bhuird North Top)",1197.0,57.08759,-3.499366,"NJ092006"],["Beinn a' Chaorainn",1083.0,57.093281,-3.577434,"NJ045013"],["Beinn a' Chaorainn",1052.0,56.928634,-4.653628,"NN386850"],["Beinn a' Chlachair",1087.0,56.869525,-4.509684,"NN471781"],["Beinn a' Chleibh",916.3,56.390231,-4.835632,"NN250256"],["Beinn a' Chochuill",980.0,56.449781,-5.068536,"NN109328"],["Beinn a' Chreachain",1080.6,56.560382,-4.647618,"NN373440"],["Beinn a' Chroin",941.4,56.331987,-4.609638,"NN387185"],["Beinn a' Ghlo-Braigh Coire Chruinn-bhalgain",1070.0,56.831083,-3.729505,"NN945724"],["Beinn a' Ghlo-Carn Liath",976.0,56.80777,-3.744106,"NN936698"],["Beinn a' Ghlo-Carn nan Gabhar",1121.9,56.839792,-3.688004,"NN971733"],["Beinn Achaladair",1038.5,56.551887,-4.694525,"NN344432"],["Beinn Alligin-Sgurr Mhor",986.0,57.59082,-5.572764,"NG865612"],["Beinn Alligin-Tom na Gruagaich",922.0,57.580519,-5.581912,"NG859601"],["Beinn an Dothaidh",1004.0,56.53013,-4.713964,"NN331408"],["Beinn Bheoil",1019.0,56.813276,-4.430662,"NN517717"],["Beinn Bhreac",931.0,57.055072,-3.553472,"NO058970"],["Beinn Bhrotain",1157.0,57.009868,-3.723797,"NN954922"],["Beinn Bhuidhe",948.5,56.326662,-4.906722,"NN203187"],["Beinn Chabhair",932.1,56.325775,-4.641485,"NN367179"],["Beinn Dearg",1084.0,57.78635,-4.929557,"NH259811"],["Beinn Dearg",1008.7,56.877346,-3.883719,"NN852778"],["Beinn Dorain",1076.0,56.50287,-4.722157,"NN325378"],["Beinn Dubhchraig",978.0,56.391295,-4.743193,"NN307254"],["Beinn Eibhinn",1103.2,56.825254,-4.542082,"NN449733"],["Beinn Eighe-Ruadh-stac Mor",1010.0,57.593735,-5.429454,"NG951611"],["Beinn Eighe-Spidean Coire nan Clach",993.0,57.582098,-5.4 ...

# %% [markdown]
# ## Fun with maps
# Now we can take the same data and plat them on a map using the very useful map library: Mapbox. Lots of info here: https://plotly.com/python/mapbox-layers/
#
# Using the (free) open street maps, we can very easily display nice maps with overlays.

# %%
import pandas as pd
us_cities = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv")

print(us_cities.head())

import plotly.express as px

fig = px.scatter_mapbox(us_cities, lat="lat", lon="lon", hover_name="City", hover_data=["State", "Population"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ### Exercise (for checkoff):
#
# Now use the same technique to display the Scottish Hills yet again with a hooverable height over the map.

# %%
import pandas as pd

print(z_data.head())

import plotly.express as px

fig = px.scatter_mapbox(z_data, lat="Latitude", lon="Longitude", hover_name="Height", hover_data=["Hill Name", "Height"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
#                     Hill Name  Height   Latitude  Longitude    Osgrid
# 0       A' Bhuidheanach Bheag   936.0  56.870342  -4.199001  NN660775
# 1               A' Chailleach   997.0  57.693800  -5.128715  NH136714
# 2               A' Chailleach   929.2  57.109564  -4.179285  NH681041
# 3  A' Chraileag (A' Chralaig)  1120.0  57.184186  -5.154837  NH094147
# 4             A' Ghlas-bheinn   918.0  57.255090  -5.303687  NH008231
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5820c11d-839b-4001-bee5-54f0d57ae358" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5820c11d-839b-4001-bee5-54f0d57ae358")) {                    Plotly.newPlot(                        "5820c11d-839b-4001-bee5-54f0d57ae358",                        [{"customdata":[["A' Bhuidheanach Bheag",936.0],["A' Chailleach",997.0],["A' Chailleach",929.2],["A' Chraileag (A' Chralaig)",1120.0],["A' Ghlas-bheinn",918.0],["A' Mhaighdean",967.0],["A' Mharconaich",973.2],["Am Basteir",934.0],["Am Bodach",1031.8],["Am Faochagach",953.0],["An Caisteal",995.8],["An Coileachan",923.9],["An Gearanach",981.4],["An Riabhachan",1129.0],["An Sgarsoch",1006.5],["An Socach",1069.0],["An Socach",944.0],["An Socach",921.0],["An Stuc",1117.1],["An Teallach-Bidein a' Ghlas Thuill",1062.5],["An Teallach-Sgurr Fiona",1058.6],["Aonach air Chrith",1019.5],["Aonach Beag",1234.0],["Aonach Beag",1115.8],["Aonach Eagach-Meall Dearg",952.2],["Aonach Eagach-Sgorr nam Fiannaidh",967.7],["Aonach Meadhoin",1001.0],["Aonach Mor",1221.0],["Beinn a' Bheithir-Sgorr Dhearg",1024.0],["Beinn a' Bheithir-Sgorr Dhonuill",1001.0],["Beinn a' Bhuird (Beinn a' Bhuird North Top)",1197.0],["Beinn a' Chaorainn",1083.0],["Beinn a' Chaorainn",1052.0],["Beinn a' Chlachair",1087.0],["Beinn a' Chleibh",916.3],["Beinn a' Chochuill",980.0],["Beinn a' Chreachain",1080.6],["Beinn a' Chroin",941.4],["Beinn a' Ghlo-Braigh Coire Chruinn-bhalgain",1070.0],["Beinn a' Ghlo-Carn Liath",976.0],["Beinn a' Ghlo-Carn nan Gabhar",1121.9],["Beinn Achaladair",1038.5],["Beinn Alligin-Sgurr Mhor",986.0],["Beinn Alligin-Tom na Gruagaich",922.0],["Beinn an Dothaidh",1004.0],["Beinn Bheoil",1019.0],["Beinn Bhreac",931.0],["Beinn Bhrotain",1157.0],["Beinn Bhuidhe",948.5],["Beinn Chabhair",932.1],["Beinn Dearg",1084.0],["Beinn Dearg",1008.7],["Beinn Dorain",1076.0],["Beinn Dubhchraig",978.0],["Beinn Eibhinn",1103.2],["Beinn Eighe-Ruadh-stac Mor",1010.0],["Beinn Eighe-Spidean Coire nan Clach",993.0],["Beinn Eunaich",989.0],["Beinn Fhada",1032.0],["Beinn Fhionnlaidh",1004.7],["Beinn Fhionnlaidh",959.0],["Beinn Ghlas",1103.0],["Beinn Ime",1011.0],["Beinn Iutharn Mhor",1045.0],["Beinn Liath Mhor",926.0],["Beinn Liath Mhor Fannaich",954.0],["Beinn Mhanach",953.0],["Beinn Mheadhoin",1182.9],["Beinn na Lap",935.0],["Beinn nan Aighenan",960.0],["Beinn Narnain",927.0],["Beinn Sgritheall",974.0],["Beinn Sgulaird",937.0],["Beinn Sheasgarnaich (Beinn Heasgarnich)",1077.4],["Beinn Tarsuinn",937.0],["Beinn Teallach",914.6],["Beinn Tulaichean",945.8],["Beinn Udlamain",1010.2],["Ben Alder",1148.0],["Ben Avon-Leabaidh an Daimh Bhuidhe",1171.0],["Ben Challum (Beinn Challuim)",1025.0],["Ben Chonzie",931.0],["Ben Cruachan",1127.0],["Ben Hope",927.0],["Ben Klibreck-Meall nan Con",962.1],["Ben Lawers",1214.0],["Ben Lomond",974.0],["Ben Lui (Beinn Laoigh)",1130.0],["Ben Macdui (Beinn Macduibh)",1309.0],["Ben More",1174.0],["Ben More",966.0],["Ben More Assynt",998.0],["Ben Nevis",1344.5],["Ben Oss",1029.0],["Ben Starav",1078.0],["Ben Vane",915.8],["Ben Vorlich",985.0],["Ben Vorlich",943.0],["Ben Wyvis-Glas Leathad Mor",1046.0],["Bidean nam Bian",1149.4],["Bidein a' Choire Sheasgaich",945.0],["Binnein Beag",943.0],["Binnein Mor",1130.0],["Bla Bheinn (Blabheinn) (Blaven)",929.0],["Braeriach",1296.0],["Broad Cairn",998.0],["Bruach na Frithe",958.0],["Buachaille Etive Beag-Stob Coire Raineach",925.0],["Buachaille Etive Beag-Stob Dubh",958.0],["Buachaille Etive Mor-Stob Dearg",1021.4],["Buachaille Etive Mor-Stob na Broige",953.4],["Bynack More",1090.0],["Cairn Bannoch",1012.0],["Cairn Gorm",1244.8],["Cairn of Claise",1064.0],["Cairn Toul",1291.0],["Carn a' Chlamain",963.5],["Carn a' Choire Bhoidheach",1109.9],["Carn a' Gheoidh",975.0],[" ...

# %% [markdown]
# ## Extra video - tableau:
#
# A great tool for data visualisation (and management) is Tableau. We won't be seeing this is detail as this is not a big data or database course, but for those of you interested here is a very quick intro:
#
# https://youtu.be/7Jl-RwkzqQ4?t=327

# %%
# play video in Colab:
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/7Jl-RwkzqQ4?t=327" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7Jl-RwkzqQ4?t=327" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# You can take it one step further and watch this demo on how to make a covid dashboard with Tableau: https://www.youtube.com/watch?v=mvpGTXRLIQc

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/v=mvpGTXRLIQc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/v=mvpGTXRLIQc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
